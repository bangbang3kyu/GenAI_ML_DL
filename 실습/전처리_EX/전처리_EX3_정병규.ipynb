# %% [markdown]
# 데이터 전처리 EX-3

# %% [markdown]
# 문제 3: 이상치 제거 (IQR 이용)

# %%
# 이상치 제거 (IQR)
import pandas as pd
df = pd.read_csv('diamonds.csv')

# carat 열에서 IQR 방식을 사용하여 이상치를 제거하세요.
Q1 = df['carat'].quantile(0.25) 
Q3 = df['carat'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("하한:", lower_bound, "상한:", upper_bound)

# 이상치 제거
df_no_outliers = df[(df['carat'] >= lower_bound) & (df['carat'] <= upper_bound)]

# 이상치 제거 후 데이터 개수 출력
print(df_no_outliers.head(5))
print(f"이상치 제거 후 데이터 개수: {len(df_no_outliers)}개")
# Out:
# 하한: -0.5599999999999999 상한: 2.0
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75
# 이상치 제거 후 데이터 개수: 52051개
